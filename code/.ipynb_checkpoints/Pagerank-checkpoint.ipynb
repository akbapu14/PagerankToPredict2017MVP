# %%
import pickle
import numpy as np

# %%
oo_dict = pickle.load(open('oo_dict.pickle', 'rb'))
of_dict = pickle.load(open('of_dict.pickle', 'rb'))
win_shares = pickle.load(open('win_shares.pickle', 'rb'))
all_star_teammates = pickle.load(open('all_star_teammates.pickle', 'rb'))
vorp = pickle.load(open('vorp.pickle', 'rb'))
d_win_shares = pickle.load(open('d_win_shares.pickle', 'rb'))
plus_minus = pickle.load(open('plus_minus.pickle', 'rb'))
games_behind = pickle.load(open('games_behind.pickle', 'rb'))

# %%
players = list(oo_dict.keys())

def calculateScore(player):
    v = vorp[player]
    o = win_shares[player]
    d = d_win_shares[player]
    g = games_behind[player]
    
    gb = 0
    if g == 0:
        gb = 6
    if 0 < g and g >= 5:
        gb = 5
    if 5 < g and g >=10:
        gb = 4
    if 10 < g and g >= 15:
        gb = 3
    if 15 < g and g >= 20:
        gb = 2
    else:
        gb = 1
    p = plus_minus[player] + 3
    return 4*v + 3 * .6 * o + 3 * .4 * d + 2 * gb + 1*p

def largestEig(A):
    n = A.shape[1]
    w,v = np.linalg.eig(A)
    firstEigen = v[:n,0]
    realEigen = np.real(firstEigen)
    #Normalize eigenvector:
    normalized = realEigen/np.linalg.norm(firstEigen, 1)
    return abs(normalized)

# %%
# Experiment 1: +/- Rating
data_mat = []
for player1 in players:
    row = []
    score1 = calculateScore(player1)
    for player2 in players:
        score2 = calculateScore(player2)
        
        a = 1
        if player1 in oo_dict:
            if player2 in oo_dict[player1]:
                a = oo_dict[player1][player2]
        #row.append(score2/(score1 + score2))
        row.append((a+50))
        
        #row.append(score2/(score1 + score2) * (a+50))
        
    data_mat.append(row)
    
data_mat = np.array(data_mat)
col_sums = data_mat.sum(axis=0)
data_mat = np.divide(data_mat, col_sums)

# %%
maxeig = largestEig(data_mat)
print(maxeig)
# Out:
# [ 0.05951148  0.05884102  0.05790616  0.05401961  0.06420707  0.05546321
#   0.05307104  0.05706243  0.05500846  0.05399859  0.05066727  0.05259887
#   0.05827813  0.05091122  0.05254725  0.0563225   0.05369567  0.05588999]

# %%
np.argsort(maxeig)
# Out:
# array([10, 13, 14, 11,  6, 16,  9,  3,  8,  5, 17, 15,  7,  2, 12,  1,  0,
#         4], dtype=int64)

# %%
# with win-shares as a more important factor
print("Best Players in the NBA Are:\n")
for p in np.argsort(maxeig)[::-1]:
    print(players[p])
# Out:
# Best Players in the NBA Are:
#
# Kevin Durant
# James Harden
# Kawhi Leonard
# DeAndre Jordan
# John Wall
# Kyle Lowry
# Gordon Hayward
# Isaiah Thomas
# LeBron James
# Marc Gasol
# Paul Millsap
# Kemba Walker
# Russell Westbrook
# Giannis Antetokounmpo
# Paul George
# Jimmy Butler
# Anthony Davis
# Carmelo Anthony

# %%
# Experiment 2: Individual Stats
data_mat = []
for player1 in players:
    row = []
    score1 = calculateScore(player1)
    for player2 in players:
        score2 = calculateScore(player2)
        
        a = 1
        if player1 in oo_dict:
            if player2 in oo_dict[player1]:
                a = oo_dict[player1][player2]
        row.append(score2/(score1 + score2))
        #row.append((a+50))
        
        #row.append(score2/(score1 + score2) * (a+50))
        
    data_mat.append(row)
    
data_mat = np.array(data_mat)
col_sums = data_mat.sum(axis=0)
data_mat = np.divide(data_mat, col_sums)

# %%
maxeig = largestEig(data_mat)
print(maxeig)
# Out:
# [ 0.04285763  0.04782103  0.05760893  0.0631542   0.04567809  0.04566023
#   0.04835661  0.05193956  0.0604793   0.0584105   0.08010481  0.07067578
#   0.05680179  0.05597696  0.06362703  0.05522905  0.04158715  0.05403136]

# %%
np.argsort(maxeig)
# Out:
# array([16,  0,  5,  4,  1,  6,  7, 17, 15, 13, 12,  2,  9,  8,  3, 14, 11,
#        10], dtype=int64)

# %%
# with win-shares as a more important factor
print("Best Players in the NBA Are:\n")
for p in np.argsort(maxeig):
    print(players[p])
# Out:
# Best Players in the NBA Are:
#
# Russell Westbrook
# James Harden
# LeBron James
# Kevin Durant
# Kawhi Leonard
# Giannis Antetokounmpo
# Kyle Lowry
# Isaiah Thomas
# Gordon Hayward
# Anthony Davis
# DeAndre Jordan
# John Wall
# Kemba Walker
# Marc Gasol
# Paul Millsap
# Jimmy Butler
# Paul George
# Carmelo Anthony

# %%
# Experiment 3: Individual Stats + Player H2H
data_mat = []
for player1 in players:
    row = []
    score1 = calculateScore(player1)
    for player2 in players:
        score2 = calculateScore(player2)
        
        a = 1
        if player1 in oo_dict:
            if player2 in oo_dict[player1]:
                a = oo_dict[player1][player2]
        #row.append(score2/(score1 + score2))
        #row.append((a+50))
        
        row.append(score2/(score1 + score2) * (a+50))
        
    data_mat.append(row)
    
data_mat = np.array(data_mat)
col_sums = data_mat.sum(axis=0)
data_mat = np.divide(data_mat, col_sums)

# %%
maxeig = largestEig(data_mat)
print(maxeig)
# Out:
# [ 0.0463971   0.05062556  0.06062001  0.06163222  0.05306158  0.04616642
#   0.04652452  0.05401407  0.05897097  0.05693223  0.07397732  0.06727357
#   0.06012547  0.05205154  0.05958002  0.05652896  0.0404643   0.05505415]

# %%
np.argsort(maxeig)
# Out:
# array([16,  5,  0,  6,  1, 13,  4,  7, 17, 15,  9,  8, 14, 12,  2,  3, 11,
#        10], dtype=int64)

# %%
# with win-shares as a more important factor
print("Best Players in the NBA Are:\n")
for p in np.argsort(maxeig):
    print(players[p])
# Out:
# Best Players in the NBA Are:
#
# Russell Westbrook
# LeBron James
# James Harden
# Giannis Antetokounmpo
# Kawhi Leonard
# Anthony Davis
# Kevin Durant
# Kyle Lowry
# Isaiah Thomas
# Gordon Hayward
# Kemba Walker
# Marc Gasol
# Jimmy Butler
# DeAndre Jordan
# John Wall
# Paul Millsap
# Paul George
# Carmelo Anthony

# %%
# players in contention for mvp this season
mvp_candidates = ["LeBron James", "Isaiah Thomas", "Russell Westbrook", "Kawhi Leonard", "James Harden"]
mvp_candidate_mat = []
for player1 in mvp_candidates:
    row = []
    score1 = calculateScore(player1)
    for player2 in mvp_candidates:
        score2 = calculateScore(player2)
        row.append(score2/(score1 + score2) * (a+50))
    mvp_candidate_mat.append(row)
mvp_candidate_mat = np.array(mvp_candidate_mat)
col_sums = mvp_candidate_mat.sum(axis=0)
mvp_candidate_mat = np.divide(mvp_candidate_mat, col_sums)

# %%
maxeig = largestEig(mvp_candidate_mat)
print(maxeig)
# Out:
# [ 0.19754674  0.22763445  0.18226103  0.2054827   0.18707508]

# %%
np.argsort(maxeig)
# Out:
# array([2, 4, 0, 3, 1], dtype=int64)

# %%
for p in np.argsort(maxeig):
    print(mvp_candidates[p])
# Out:
# Russell Westbrook
# James Harden
# LeBron James
# Kawhi Leonard
# Isaiah Thomas

# %%
# Extra: Simulate 7 game series between two teams of all stars
# Just a simple fun application of Markov Chains with changing probabilites
# TODO: Fill in with players of your choice from the all star list, just make sure they are unique
teamA = ["LeBron James", "Kevin Durant", "Carmelo Anthony", "Kawhi Leonard", "Anthony Davis"]
teamB = ["James Harden", "Russell Westbrook", "Paul George", "Jimmy Butler", "John Wall"]

def calculate_avg_score(teamA, teamB):
    teamA_avg = 0
    teamB_avg = 0
    for player in teamA:
        teamA_avg += calculateScore(player)
    teamA_avg /= 5
    
    for player in teamB:
        teamB_avg += calculateScore(player)
    
    teamB_avg /= 5
    
    return teamA_avg, teamB_avg

a_score, b_score = calculate_avg_score(teamA, teamB)

# %%
pr_a = a_score*1.0/(a_score + b_score)
pr_b = b_score*1.0/(a_score + b_score)

print (pr_a)
print (pr_b)
# Out:
# 0.5022175290390708
# 0.49778247096092926

# %%
import random
import matplotlib.pyplot as plt

def plot_wins(a_wins, a_games, b_wins, b_games):
    f, axarr = plt.subplots(2, sharex=True)
    axarr[0].scatter(a_wins, a_games)
    axarr[0].set_title('Number of wins to win series for Team A')
    axarr[1].scatter(b_wins, b_games)
    axarr[1].set_title('Number of wins to win series for Team B')
    
    print("Team A won " + str(len(a_games)) + " games")
    print("Team A took on average " + str(sum(a_games) * 1.0 /len(a_games)) + " games to win")
    
    print("Team B won " + str(len(b_games)) + " games")
    print("Team B took on average " + str(sum(b_games) * 1.0 /len(b_games)) + " games to win")
    plt.show()

# %%
# Simulation 1: Winning Team Gets Home Court Advantage

def simulation1(num_simulations, handicap, state):
    a_home_adv = pr_a + handicap
    b_home_adv = pr_b + handicap
    a_away_adv = pr_a - handicap
    b_away_adv = pr_b - handicap

    mat = [[a_home_adv, b_away_adv], [a_away_adv, b_home_adv]]

    a_wins = []
    a_num_games = []
    b_wins = []
    b_num_games = []
    for sim in range(num_simulations):
        teamA_wins = 0
        teamB_wins = 0
        for i in range(7):
            state = np.matmul(state, mat)
            rand = random.uniform(0,1)
            if rand <= state[0]:
                teamA_wins += 1
                state = [1,0]
            else:
                teamB_wins += 1
                state = [0,1]

            if teamA_wins == 4:
                a_wins.append(sim)
                a_num_games.append(i+1)
                break
            elif teamB_wins == 4:
                b_wins.append(sim)
                b_num_games.append(i+1)
                break
    return a_wins, a_num_games, b_wins, b_num_games

# %%
state = [1, 0] 
a_wins, a_num_games, b_wins, b_num_games = simulation1(100, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 46 games
# Team A took on average 5.804347826086956 games to win
# Team B won 54 games
# Team B took on average 5.703703703703703 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(100, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 52 games
# Team A took on average 5.6923076923076925 games to win
# Team B won 48 games
# Team B took on average 5.604166666666667 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(100, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 52 games
# Team A took on average 5.634615384615385 games to win
# Team B won 48 games
# Team B took on average 5.604166666666667 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(500, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 259 games
# Team A took on average 5.722007722007722 games to win
# Team B won 241 games
# Team B took on average 5.726141078838174 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(500, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 267 games
# Team A took on average 5.677902621722846 games to win
# Team B won 233 games
# Team B took on average 5.669527896995708 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(500, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 240 games
# Team A took on average 5.570833333333334 games to win
# Team B won 260 games
# Team B took on average 5.657692307692308 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(1000, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 498 games
# Team A took on average 5.771084337349397 games to win
# Team B won 502 games
# Team B took on average 5.749003984063745 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(1000, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 512 games
# Team A took on average 5.658203125 games to win
# Team B won 488 games
# Team B took on average 5.665983606557377 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(1000, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 497 games
# Team A took on average 5.456740442655936 games to win
# Team B won 503 games
# Team B took on average 5.576540755467197 games to win

# %%
state = [0, 1] 
a_wins, a_num_games, b_wins, b_num_games = simulation1(100, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 51 games
# Team A took on average 5.7254901960784315 games to win
# Team B won 49 games
# Team B took on average 5.591836734693878 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(100, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 56 games
# Team A took on average 6.017857142857143 games to win
# Team B won 44 games
# Team B took on average 5.568181818181818 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(100, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 58 games
# Team A took on average 5.4655172413793105 games to win
# Team B won 42 games
# Team B took on average 5.9523809523809526 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(500, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 260 games
# Team A took on average 5.876923076923077 games to win
# Team B won 240 games
# Team B took on average 5.795833333333333 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(500, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 255 games
# Team A took on average 5.690196078431373 games to win
# Team B won 245 games
# Team B took on average 5.710204081632653 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(500, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 268 games
# Team A took on average 5.619402985074627 games to win
# Team B won 232 games
# Team B took on average 5.573275862068965 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(1000, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 539 games
# Team A took on average 5.855287569573284 games to win
# Team B won 461 games
# Team B took on average 5.843817787418655 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(1000, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 532 games
# Team A took on average 5.701127819548872 games to win
# Team B won 468 games
# Team B took on average 5.64957264957265 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation1(1000, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 481 games
# Team A took on average 5.542619542619542 games to win
# Team B won 519 games
# Team B took on average 5.570327552986512 games to win

# %%
# Simulation 2: NBA Style
# Games 1, 2, 5, 7 --> Higher Ranked Team
# Games 3, 4, 6 --> lower Ranked Team

def simulation2(num_simulations, handicap):
    a_home_adv = pr_a + handicap
    b_home_adv = pr_b + handicap
    a_away_adv = pr_a - handicap
    b_away_adv = pr_b - handicap

    mat = [[a_home_adv, b_away_adv], [a_away_adv, b_home_adv]]

    a_wins = []
    a_num_games = []
    b_wins = []
    b_num_games = []
    for sim in range(num_simulations):
        teamA_wins = 0
        teamB_wins = 0
        for i in range(7):
            if i+1 in [1,2,5,7]:
                state = [1, 0]
            else:
                state = [0, 1]
            state = np.matmul(state, mat)
            rand = random.uniform(0,1)
            if rand <= state[0]:
                teamA_wins += 1
            else:
                teamB_wins += 1

            if teamA_wins == 4:
                a_wins.append(sim)
                a_num_games.append(i+1)
                break
            elif teamB_wins == 4:
                b_wins.append(sim)
                b_num_games.append(i+1)
                break
    return a_wins, a_num_games, b_wins, b_num_games

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation2(100, 0)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 49 games
# Team A took on average 5.714285714285714 games to win
# Team B won 51 games
# Team B took on average 5.9411764705882355 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation2(100, 0.05)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 41 games
# Team A took on average 5.975609756097561 games to win
# Team B won 59 games
# Team B took on average 5.983050847457627 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation2(100, 0.1)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 55 games
# Team A took on average 5.872727272727273 games to win
# Team B won 45 games
# Team B took on average 5.733333333333333 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation2(500, 0)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 249 games
# Team A took on average 5.779116465863454 games to win
# Team B won 251 games
# Team B took on average 5.820717131474104 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation2(500, 0.05)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 249 games
# Team A took on average 5.907630522088353 games to win
# Team B won 251 games
# Team B took on average 5.816733067729084 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation2(500, 0.1)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 262 games
# Team A took on average 5.778625954198473 games to win
# Team B won 238 games
# Team B took on average 5.823529411764706 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation2(1000, 0)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 490 games
# Team A took on average 5.844897959183673 games to win
# Team B won 510 games
# Team B took on average 5.8 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation2(1000, 0.05)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 525 games
# Team A took on average 5.7352380952380955 games to win
# Team B won 475 games
# Team B took on average 5.797894736842105 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation2(1000, 0.1)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 543 games
# Team A took on average 5.808471454880294 games to win
# Team B won 457 games
# Team B took on average 5.805251641137856 games to win

# %%
# Simulation 3: Losing Team Gets Home Court Advantage

def simulation3(num_simulations, handicap, state):
    a_home_adv = pr_a + handicap
    b_home_adv = pr_b + handicap
    a_away_adv = pr_a - handicap
    b_away_adv = pr_b - handicap

    mat = [[a_home_adv, b_away_adv], [a_away_adv, b_home_adv]]

    a_wins = []
    a_num_games = []
    b_wins = []
    b_num_games = []
    for sim in range(num_simulations):
        teamA_wins = 0
        teamB_wins = 0
        for i in range(7):
            state = np.matmul(state, mat)
            rand = random.uniform(0,1)
            if rand <= state[0]:
                teamA_wins += 1
                state = [0,1]
            else:
                teamB_wins += 1
                state = [1,0]

            if teamA_wins == 4:
                a_wins.append(sim)
                a_num_games.append(i+1)
                break
            elif teamB_wins == 4:
                b_wins.append(sim)
                b_num_games.append(i+1)
                break
    return a_wins, a_num_games, b_wins, b_num_games

# %%
state = [1, 0] 
a_wins, a_num_games, b_wins, b_num_games = simulation3(100, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 42 games
# Team A took on average 5.714285714285714 games to win
# Team B won 58 games
# Team B took on average 5.827586206896552 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(100, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 41 games
# Team A took on average 5.804878048780488 games to win
# Team B won 59 games
# Team B took on average 5.966101694915254 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(100, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 50 games
# Team A took on average 5.72 games to win
# Team B won 50 games
# Team B took on average 6.02 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(500, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 256 games
# Team A took on average 5.79296875 games to win
# Team B won 244 games
# Team B took on average 5.692622950819672 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(500, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 249 games
# Team A took on average 6.0 games to win
# Team B won 251 games
# Team B took on average 6.0199203187251 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(500, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 269 games
# Team A took on average 5.95910780669145 games to win
# Team B won 231 games
# Team B took on average 6.073593073593074 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(1000, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 511 games
# Team A took on average 5.829745596868885 games to win
# Team B won 489 games
# Team B took on average 5.750511247443763 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(1000, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 494 games
# Team A took on average 5.8603238866396765 games to win
# Team B won 506 games
# Team B took on average 5.958498023715415 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(1000, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 510 games
# Team A took on average 6.041176470588235 games to win
# Team B won 490 games
# Team B took on average 6.03265306122449 games to win

# %%
state = [0, 1] 
a_wins, a_num_games, b_wins, b_num_games = simulation3(100, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 54 games
# Team A took on average 5.888888888888889 games to win
# Team B won 46 games
# Team B took on average 6.0 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(100, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 56 games
# Team A took on average 6.035714285714286 games to win
# Team B won 44 games
# Team B took on average 6.0 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(100, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 49 games
# Team A took on average 6.061224489795919 games to win
# Team B won 51 games
# Team B took on average 5.8431372549019605 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(500, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 274 games
# Team A took on average 5.806569343065694 games to win
# Team B won 226 games
# Team B took on average 5.752212389380531 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(500, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 267 games
# Team A took on average 5.861423220973783 games to win
# Team B won 233 games
# Team B took on average 6.047210300429184 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(500, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 270 games
# Team A took on average 6.12962962962963 games to win
# Team B won 230 games
# Team B took on average 5.917391304347826 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(1000, 0, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 507 games
# Team A took on average 5.830374753451676 games to win
# Team B won 493 games
# Team B took on average 5.776876267748479 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(1000, 0.05, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 504 games
# Team A took on average 5.992063492063492 games to win
# Team B won 496 games
# Team B took on average 5.961693548387097 games to win

# %%
a_wins, a_num_games, b_wins, b_num_games = simulation3(1000, 0.1, state)
plot_wins(a_wins, a_num_games, b_wins, b_num_games)
# Out:
# Team A won 516 games
# Team A took on average 6.021317829457364 games to win
# Team B won 484 games
# Team B took on average 6.045454545454546 games to win
